# %%
import numpy as np

M = 10
nu = 0
T = int(1e4)
mu1 = 1

# %%
import numpy as np
import focus_implementation as focus

np.random.seed()
data = focus.generate_data(M, T, nu, mu1)
changepoint_history, glr_history = focus.generate_history(data)

# %%
import matplotlib.pyplot as plt
plt.plot(changepoint_history[:200])

# %%
for i in range(10):
    plt.plot(glr_history[:200,i])

# %%
glr_history
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         4.64801531e+03, 4.64832270e+03, 4.64868043e+03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.31208409e+00, 1.31208409e+00, 1.31208409e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         5.90941732e-01, 5.90941732e-01, 5.90941732e-01],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         4.25470854e+00, 4.25470854e+00, 4.25470854e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.63502619e+00, 2.63502619e+00, 2.63502619e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.46552664e+00, 1.46552664e+00, 1.46552664e+00]])
